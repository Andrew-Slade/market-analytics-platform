# %%
import duckdb

# %%
con = duckdb.connect()
con.execute("""
CREATE OR REPLACE VIEW market_view AS
SELECT *
FROM read_parquet('/home/aslade/personal_projects/market-analytics-platform/data/');
""")

# %%
df = con.sql("""
    SELECT *
    FROM market_view
    WHERE year = 2026 AND month = 6 AND day = 24 and product_id='BTC-USD'
    """).fetchdf()
df
# Out:
#          type      sequence product_id     price  open_24h    volume_24h  \
# 0      ticker  131255198622    BTC-USD  60661.29  62388.98  14724.558640
# 1      ticker  131255199794    BTC-USD  60657.89  62388.98  14724.558640
# 2      ticker  131255199899    BTC-USD  60657.89  62388.98  14724.558640
# 3      ticker  131255200395    BTC-USD  60657.89  62388.98  14724.558734
# 4      ticker  131255200397    BTC-USD  60657.89  62388.98  14724.558781
# ...       ...           ...        ...       ...       ...           ...
# 51721  ticker  131261287472    BTC-USD  60971.50  62509.96  15235.458841
# 51722  ticker  131261287474    BTC-USD  60971.50  62509.96  15235.459173
# 51723  ticker  131261287476    BTC-USD  60971.50  62509.96  15235.463014
# 51724  ticker  131261287492    BTC-USD  60971.02  62509.96  15235.468263
# 51725  ticker  131261287494    BTC-USD  60969.74  62509.96  15235.473511
#
#         low_24h  high_24h     volume_30d  best_bid  ...  best_ask  \
# ...
